# %% [markdown]
# # Setup

# %%
# %pip install --upgrade --quiet langchain langchain-community langchain-openai neo4j
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os 

os.environ["NEO4J_URI"] = 'bolt://localhost:7687'
os.environ["NEO4J_USERNAME"] = 'neo4j'
os.environ["NEO4J_PASSWORD"] = 'rlaalsdud12'

# %%
import pandas as pd 

movies = pd.read_csv("netflix_titles.csv")

movies
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
from langchain_community.graphs import Neo4jGraph

graph = Neo4jGraph()

# Import movie information

movies_query = """
LOAD CSV WITH HEADERS FROM 
'https://raw.githubusercontent.com/tomasonjo/blog-datasets/main/movies/movies_small.csv'
AS row
MERGE (m:Movie {id:row.movieId})
SET m.released = date(row.released),
    m.title = row.title,
    m.imdbRating = toFloat(row.imdbRating)
FOREACH (director in split(row.director, '|') | 
    MERGE (p:Person {name:trim(director)})
    MERGE (p)-[:DIRECTED]->(m))
FOREACH (actor in split(row.actors, '|') | 
    MERGE (p:Person {name:trim(actor)})
    MERGE (p)-[:ACTED_IN]->(m))
FOREACH (genre in split(row.genres, '|') | 
    MERGE (g:Genre {name:trim(genre)})
    MERGE (m)-[:IN_GENRE]->(g))
"""

graph.query(movies_query)
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/langchain_community/graphs/neo4j_graph.py:350, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     349 try:
# --> 350     self._driver.verify_connectivity()
#     351 except neo4j.exceptions.ServiceUnavailable:
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/driver.py:1032, in Driver.verify_connectivity(self, **config)
#    1031 session_config = self._read_session_config(config)
# -> 1032 self._get_server_info(session_config)
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/driver.py:1243, in Driver._get_server_info(self, session_config)
#    1242 with self._session(session_config) as session:
# -> 1243     return session._get_server_info()
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/work/session.py:172, in Session._get_server_info(self)
#     171 assert not self._connection
# --> 172 self._connect(READ_ACCESS, liveness_check_timeout=0)
#     173 server_info = self._connection.server_info
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/work/session.py:130, in Session._connect(self, access_mode, **acquire_kwargs)
#     129 try:
# --> 130     super()._connect(
#     131         access_mode, auth=self._config.auth, **acquire_kwargs
#     132     )
#     133 except asyncio.CancelledError:
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/work/workspace.py:182, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     181 acquire_kwargs_.update(acquire_kwargs)
# --> 182 self._connection = self._pool.acquire(**acquire_kwargs_)
#     183 self._connection_access_mode = access_mode
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:526, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout)
#     525 deadline = Deadline.from_timeout_or_deadline(timeout)
# --> 526 return self._acquire(
#     527     self.address, auth, deadline, liveness_check_timeout
#     528 )
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:313, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout)
#     312 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 313 return connection_creator()
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:163, in IOPool._acquire_new_later.<locals>.connection_creator()
#     162 try:
# --> 163     connection = self.opener(
#     164         address, auth or self.pool_config.auth, deadline
#     165     )
#     166 except ServiceUnavailable:
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:500, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     499 def opener(addr, auth_manager, deadline):
# --> 500     return Bolt.open(
#     501         addr, auth_manager=auth_manager, deadline=deadline,
#     502         routing_context=None, pool_config=pool_config
#     503     )
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:488, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     487 try:
# --> 488     connection.hello()
#     489 finally:
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/io/_bolt5.py:574, in Bolt5x2.hello(self, dehydration_hooks, hydration_hooks)
#     573 self.send_all()
# --> 574 self.fetch_all()
#     575 check_supported_server_product(self.server_info.agent)
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:864, in Bolt.fetch_all(self)
#     863 while not response.complete:
# --> 864     detail_delta, summary_delta = self.fetch_message()
#     865     detail_count += detail_delta
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:850, in Bolt.fetch_message(self)
#     847 tag, fields = self.inbox.pop(
#     848     hydration_hooks=self.responses[0].hydration_hooks
#     849 )
# --> 850 res = self._process_message(tag, fields)
#     851 self.idle_since = monotonic()
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/io/_bolt5.py:369, in Bolt5x0._process_message(self, tag, fields)
#     368 try:
# --> 369     response.on_failure(summary_metadata or {})
#     370 except (ServiceUnavailable, DatabaseUnavailable):
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/neo4j/_sync/io/_common.py:281, in LogonResponse.on_failure(self, metadata)
#     280 Util.callback(handler)
# --> 281 raise Neo4jError.hydrate(**metadata)
#
# AuthError: {code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.}
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 from langchain_community.graphs import Neo4jGraph
# ----> 3 graph = Neo4jGraph()
#       5 # Import movie information
#       7 movies_query = """
#       8 LOAD CSV WITH HEADERS FROM
#       9 'https://raw.githubusercontent.com/tomasonjo/blog-datasets/main/movies/movies_small.csv'
#    (...)
#      23     MERGE (m)-[:IN_GENRE]->(g))
#      24 """
#
# File ~/.local/share/virtualenvs/LLM_Langchain_APP-7aD6jX0r/lib/python3.10/site-packages/langchain_community/graphs/neo4j_graph.py:357, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     352     raise ValueError(
#     353         "Could not connect to Neo4j database. "
#     354         "Please ensure that the url is correct"
#     355     )
#     356 except neo4j.exceptions.AuthError:
# --> 357     raise ValueError(
#     358         "Could not connect to Neo4j database. "
#     359         "Please ensure that the username and password are correct"
#     360     )
#     361 # Set schema
#     362 if refresh_schema:
#
# ValueError: Could not connect to Neo4j database. Please ensure that the username and password are correct
